# %%
print('hello')
# Out:
# hello

# %% [markdown]
# # hello

# %%
print("my name")
# Out:
# my name

# %%
while True:
    if user_input == input("나: ")
# Out:
#   Cell In[4], line 2
#     if user_input == input("나: ")
#                                  ^
# SyntaxError: expected ':'
