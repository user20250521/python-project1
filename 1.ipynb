# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print("챗봇: 안녕하세요, 저는 간단한 챗봇입니다. 무엇을 도와드릴까요? (종료를 원하면 ('exit')")
    while True:
    
    if user_input

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 20260320

# %% [markdown]
# ## 여긴가

# %% [markdown]
# # 여기서부터
